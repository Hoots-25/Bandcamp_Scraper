# %%
# Open artist index
# Count how many pages there are
# Open the artist page
# 1. Check if there are music/artist tabs
# 1.1 If there are artist tabs ignore them (they probably exist elsewhere and will get picked up)
# 1.2 If there are music tabs ignore them (they probably exist elsewhere and will get picked up)
# 2. Check if there are multiple songs/tracks on the artist page
# 2.1 If it is a track, open the page, get info and write to csv (A single track will not contain a song duration)
# 2.2 if it is an album, open the page, get info and write to csv
# 3. Check if all the artist page is also the album page (The artist page will only contain tracks and nothing else)
# 3.1 Get album information, and write it to a csv
# 4. Something bad most likely happened and you should skip and go to the next artist

##########################################################################################################################
##########################################################################################################################


##########################################################################################################################
# Define Functions to be Used
##########################################################################################################################
# GET_MAX_PAGES(soup)
# Get the maximum page value to use as the end point (This is probably a waste of a function since you only need it 1x)

def get_max_pages(soup):
    n_pages = []
    for page in soup.find_all("a", {"rel": "nofollow"}):
        n_pages.append(int(page.text))
    max_pages = max(n_pages)
    return max_pages


##########################################################################################################################
# GET_TAB_CHECK()
# This function will check if there are multiple tabs on the artist page.
# A return value of 0: There is at least one tab
# A return value of 1 mean there are no tabs

def get_tab_check(asrtist_soup):
    check_1 = artist_soup.find("a", {"href": "/artists"})
    check_2 = artist_soup.find("a", {"href": "/music"})

    if check_1 is None or check_2 is None:
        # If the there is no music OR no Artist Tab
        tab_check = 0

    else:
        # Tabs exist
        tab_check = 1

    return tab_check


##########################################################################################################################
# GET_SINGLE_ALBUM_INFO(soup)
# This function should be called when on an artists page and they only have a single album (multiple tracks)

def get_single_album_data(content_soup):
    artist_song = []
    song_dur = []
    artist_tags = []

    # Get Artist Name
    artist_name = content_soup.find("span", {"itemprop": "byArtist"}).text
    artist_name = artist_name.replace("\n", "")
    artist_name.lstrip().rstrip()
    # print(artist_name)

    # Get Album Name
    album_name = content_soup.find("h2", {"class": "trackTitle"}).text
    album_name = album_name.replace("\n", "")

    # Get Artist Location
    artist_loc = content_soup.find("span", {"class": "location secondaryText"}).text
    if artist_loc == "":
        artist_loc = "N/A"

    # Get the date
    try:
        album_date = content_soup.find("meta", {"itemprop": "datePublished"})["content"]
        album_date = datetime.datetime.strptime(album_date, "%Y%m%d").strftime("%m/%d/%Y")

    except:
        album_date = "N/A"
    print(album_date)
    # Get Album Tags
    for tags in content_soup.find_all("a", {"class": "tag"}):
        artist_tags.append(tags.text)

    # Get Songs
    try:
        content_soup.find_all("span", {"itemprop": "name"})
        for song in content_soup.find_all("span", {"itemprop": "name"}):
            artist_song.append(song.text)
        # artist_song = [artist_song.replace(" ", "") for artist_song in song]
        # artist_song = [artist_song.replace("\n", "") for artist_song in song]
    except:
        artist_song = album_name

    # Get Song Durations
    for x in content_soup.find_all("div", {"class": "title"}):
        try:
            y = x.find("span", {"class": "time secondaryText"})
            song_dur.append(y.text)
        except:
            song_dur.append("N/A")  # Pass N/A if song length is missing

    data = [artist_name, album_name, artist_loc, album_date, artist_tags, artist_song, song_dur]
    return data


##########################################################################################################################
# GET_SINGLE_TRACK_DATA(soup)
# This function should be called when on an artists page and they only have a single track instead of an album as a page

def get_single_track_data(content_soup):
    artist_song = []
    song_dur = []
    artist_tags = []

    # Get Artist Name
    artist_name = content_soup.find("span", {"itemprop": "byArtist"}).text
    artist_name = artist_name.replace("\n", "")
    artist_name = artist_name.lstrip().rstrip()

    # print(artist_name)

    # Get Album Name
    album_name = content_soup.find("h2", {"class": "trackTitle"}).text
    album_name = album_name.replace("\n", "")

    # Get Artist Location
    artist_loc = content_soup.find("span", {"class": "location secondaryText"}).text
    if artist_loc == "":
        artist_loc = "N/A"

    # Get the date
    try:
        album_date = content_soup.find("meta", {"itemprop": "datePublished"})["content"]
        album_date = datetime.datetime.strptime(album_date, "%Y%m%d").strftime("%m/%d/%Y")
    except:
        album_date = "N/A"
    print(album_date)
    # Get Album Tags
    for tags in content_soup.find_all("a", {"class": "tag"}):
        artist_tags.append(tags.text)

        # Get Song
    artist_song = album_name  # Keep the track name the same as the album since

    # Get Song Durations
    song_dur = "N/A"  # Unable to find the duration of the song via beautifulSoup for some reason, so ignore (FIX THIS)

    data = [artist_name, album_name, artist_loc, album_date, artist_tags, artist_song, song_dur]
    return data


##########################################################################################################################
# WRITE_TO_CSV(data)
# Self-explanatory

def write_to_csv(data):
    # Pull out the data from the function
    ARTIST_ = data[0]
    ALBUM_ = data[1]
    LOC_ = data[2]
    DATE_ = data[3]
    TAGS_ = data[4]
    SONG_ = data[5]
    DUR_ = data[6]

    song_array = np.array(SONG_)
    n_songs = song_array.size

    if n_songs > 1:
        for i in range(0, n_songs):
            # myData = writer.writerow({'Artist':ARTIST_,'Album':ALBUM_,'Song':SONG_[i],'Length':DUR_[i],'Tags':TAGS_,'Date':DATE_,'Location':LOC_})
            writer.writerow(
                {'Artist': ARTIST_, 'Album': ALBUM_, 'Song': SONG_[i], 'Length': DUR_[i], 'Tags': TAGS_, 'Date': DATE_,
                 'Location': LOC_})
    elif n_songs == 1:
        myData = writer.writerow(
            {'Artist': ARTIST_, 'Album': str(ALBUM_), 'Song': str(SONG_), 'Length': DUR_, 'Tags': TAGS_, 'Date': DATE_,
             'Location': LOC_})
    else:
        pass
    return


##########################################################################################################################
##########################################################################################################################

# Import all the necessary packages
import urllib.request, urllib.error
from bs4 import BeautifulSoup
import csv
import datetime
import string
import numpy as np

##########################################################################################################################

# Start the main code
artist_index_url = "https://bandcamp.com/artist_index"  # Set the url for all artists
html = urllib.request.urlopen(artist_index_url)  # Open the page
soup = BeautifulSoup(html, 'html.parser')  # Use beautifulSoup to access html

max_pages = get_max_pages(soup)  # Find the maximum # pages so you know how long to run the for loop
currentDT = datetime.datetime.now()
currentDT = currentDT.strftime("%Y-%m-%d_%H.%M.%S")

# Create/Open the CSV File you will be writing too
with open('Bandcamp_MASTER_' + str(currentDT) + '.csv', 'w', encoding='utf-8-sig') as csvfile:
    fieldnames = ['Artist', 'Album', 'Location', 'Song', 'Length', 'Tags', 'Date']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames, lineterminator='\n')
    writer.writeheader()

    page_url = "?page=1"  # Initialize the 1st page as default

    # This will loop for every page available (1-->max_pages)
    for page in range(2650, max_pages):
        try:
            # Get the url for the page number and open it with BeautifulSoup
            page_url = page_url.replace(page_url[len(page_url) - 1], str(page))  # replace the previous page number
            page_html = artist_index_url + page_url  # create the new link for the next page to scan
            page_html = urllib.request.urlopen(page_html)  # open the next page
            soup = BeautifulSoup(page_html, 'html.parser')  # Pull the data from the next page

            # Get the artists on that page and append it to the complete artist list

            artist_class = soup.find('ul',
                                     {"class": "item_list"})  # Finds the html section that includes all artist links
            for a_link in artist_class.find_all('a', href=True):
                # print(a_link["href"]) # print the artist's url
                artist_url = a_link["href"]  # create variable for artist's url
                artist_html = urllib.request.urlopen(artist_url)  # open the artist's url
                print(artist_url)
                artist_soup = BeautifulSoup(artist_html, "html.parser")  # Pull the data from artist's url

                tab_check = get_tab_check(artist_soup)

                if tab_check == 0:
                    # If there are no tabs

                    post_check = artist_soup.find("ol", {
                        "data-edit-callback": "/music_reorder"})  # looks for a grid with multiple albums/tracks

                    if post_check is not None:
                        # Confirms that there are multiple posts
                        for n_posts in post_check.find_all("a", href=True):
                            # Enter the artist page and identify the artist's content
                            url = artist_url + n_posts["href"]
                            html = urllib.request.urlopen(url)
                            content_soup = BeautifulSoup(html, "html.parser")

                            if "track" in n_posts["href"]:
                                # The soup is a track
                                print(1)
                                # print(url)
                                data = get_single_track_data(content_soup)
                                write_to_csv(data)

                            elif "album" in n_posts["href"]:
                                # the soup is an album
                                print(2)
                                data = get_single_album_data(content_soup)
                                write_to_csv(data)
                            else:
                                # Skip to the next artist if it was neither
                                continue
                    else:
                        # There is one post, so open up their releases
                        print(3)
                        # if it's an album
                        url = artist_url + "/releases"
                        html = urllib.request.urlopen(url)
                        content_soup = BeautifulSoup(html, "html.parser")

                        # check if there are multiple tracks
                        post_check2 = artist_soup.find("table", {"class": "track_list track_table"})

                        if post_check2 is not None:
                            # There are multiple tracks
                            data = get_single_album_data(content_soup)
                            write_to_csv(data)
                        else:
                            data = get_single_track_data(content_soup)
                            write_to_csv(data)

                else:
                    # If there are tabs, skip and go to the next artist
                    continue
        except Exception:
                continue
# Out:
# https://martinparis.bandcamp.com
# 3
# 06/30/2011
# https://whateverthatmeans.bandcamp.com
# 2
# 07/27/2016
# 2
# 12/19/2014
# 2
# 05/03/2014
# 2
# 05/03/2014
# 2
# 07/09/2011
# 2
# 04/03/2010
# https://sexualreproductivesystems.bandcamp.com
# 3
# 02/05/2012
# https://fairfaxalaska.bandcamp.com
# 3
# 06/29/2011
# https://guerman.bandcamp.com
# 2
# 01/01/2016
# 2
# 09/02/2013
# 2
# 06/29/2011
# https://katafuta.bandcamp.com
# 2
# 04/16/2014
# 2
# 03/29/2014
# 2
# 06/04/2013
# https://magneticstripper.bandcamp.com
# 3
# 06/18/2009
# https://simonkarolis.bandcamp.com
# 2
# 10/30/2013
# 1
# 06/02/2016
# 2
# 10/23/2014
# 2
# 12/25/2012
# 1
# 09/20/2012
# https://nova-scotia.bandcamp.com
# 3
# 04/16/2009
# https://dangrecords.bandcamp.com
# 2
# 05/15/2018
# 2
# 09/23/2017
# 2
# 08/26/2016
# 2
# 10/25/2016
# 2
# 07/21/2015
# 2
# 02/17/2012
# 2
# 03/16/2015
# 2
# 09/04/2012
# 2
# 01/01/2009
# 2
# 10/23/2012
# 2
# 03/24/2014
# 2
# 04/07/2012
# 2
# 05/01/2013
# 2
# 05/20/2012
# 2
# 10/15/2011
# 2
# 07/15/2011
# 2
# 06/19/2010
# 1
# 09/12/2011
# 1
# 09/06/2011
# 2
# 03/17/2012
# https://ralphwaldo.bandcamp.com
# 3
# 12/12/1977
# https://designbynv.bandcamp.com
# 2
# 05/03/2019
# 2
# 11/27/2018
# 2
# 12/05/2018
# 2
# 04/13/2019
# 2
# 02/05/2017
# 2
# 03/27/2017
# 2
# 12/05/2018
# 2
# 05/20/2017
# 2
# 11/08/2018
# 2
# 12/13/2016
# 2
# 01/29/2017
# 2
# 05/15/2017
# 2
# 01/19/2017
# 2
# 05/19/2017
# 2
# 03/03/2013
# 2
# 01/17/2017
# 2
# 05/20/2017
# 2
# 01/17/2017
# 2
# 11/17/2016
# 2
# 04/29/2017
# 1
# 05/24/2017
# 2
# 12/20/2010
# 2
# 12/05/2018
# 2
# 07/29/2017
# 2
# 01/01/2009
# 2
# 06/06/2008
# https://dsmiley.bandcamp.com
# 3
# 04/24/2019
# https://evolvedasnone.bandcamp.com
# 3
# 04/01/2009
# https://ronniehenn.bandcamp.com
# 3
# 12/01/2010
# https://lintech.bandcamp.com
# 2
# 01/01/2018
# 2
# 02/20/2014
# 2
# 01/01/2012
# 2
# 06/30/2011
# 2
# 11/20/2010
# https://swainmusic.bandcamp.com
# 3
# 08/01/2011
# https://redsummertape.bandcamp.com
# 3
# 04/01/2011
# https://picpacklabel.bandcamp.com
# 3
# 05/26/2011
# https://grinderonhead.bandcamp.com
# 3
# 09/12/2013
# https://xingschool.bandcamp.com
# 3
# 02/24/2011
# https://edizionivalgrande.bandcamp.com
# 1
# 09/26/2018
# 2
# 03/21/2018
# https://simonferet.bandcamp.com
# 1
# 05/25/2011
# 1
# 05/01/2009
# https://justlexi.bandcamp.com
# 3
# 06/29/2012
# https://myselftheband.bandcamp.com
# 3
# 05/01/2011
# https://brainforbreakfast.bandcamp.com
# 3
# 06/18/2011
# https://intermusic.bandcamp.com
# 3
# 01/07/2011
# https://naserito.bandcamp.com
# 1
# 06/29/2011
# 1
# 06/29/2011
# 1
# 06/30/2011
# 1
# 06/30/2011
# 1
# 06/29/2011
# 1
# 06/29/2011
# 1
# N/A
# 1
# 05/12/2018
# https://adsarto.bandcamp.com
# 3
# N/A
# https://thelastgangintown.bandcamp.com
# 3
# 07/01/2011
# https://sameden.bandcamp.com
# 3
# 08/09/2014
# https://ryangarrett7.bandcamp.com
# 3
# N/A
# https://tojinbo.bandcamp.com
# 3
# 06/24/2011
# https://iamevilrecords.bandcamp.com
# 2
# 03/08/2019
# 2
# 09/13/2006
# 2
# 12/18/2013
# 2
# 12/18/2005
# 2
# 12/18/2010
# 2
# 12/25/2007
# 2
# 06/02/2011
# 2
# 08/02/2010
# 2
# 02/25/2011
# 2
# 02/10/2011
# 2
# 01/04/2011
# 2
# 04/12/2005
# 2
# 06/12/2007
# https://drenster.bandcamp.com
# 1
# 01/24/2014
# 1
# 06/24/2013
# 2
# 03/06/1996
# https://thevega-mifflinband.bandcamp.com
# 2
# 03/15/2017
# 2
# 10/25/2011
# 2
# 09/06/2009
# https://eneeks.bandcamp.com
# 3
# 01/02/2017
# https://mydwem.bandcamp.com
# 1
# 12/23/2015
# 2
# 12/01/2015
# 2
# 10/02/2015
# 2
# 12/03/2014
# 1
# 12/12/2013
# 1
# 02/06/2013
# 1
# 01/01/2011
# 1
# 10/26/2010
# 2
# 11/12/2012
# 1
# 08/16/2013
# https://coraje.bandcamp.com
# 3
# 12/10/2014
# https://adrianchampion.bandcamp.com
# 3
# 07/20/2011
# https://losdias.bandcamp.com
# 3
# 01/15/2011
# https://jerrycane.bandcamp.com
# 3
# 12/18/2009
# https://cocainepcp.bandcamp.com
# 3
# 06/02/2018
# https://cenesthesie.bandcamp.com
# 3
# 09/11/2013
# https://echoshell.bandcamp.com
# 3
# 05/05/2010
# https://gogreen.bandcamp.com
# 1
# 03/02/2016
# 1
# 07/20/2015
# 2
# 07/04/2011
# 2
# 11/05/2010
# 2
# 06/20/2002
# https://atomizador.bandcamp.com
# 3
# 12/20/2017
# https://davidbroza.bandcamp.com
# 1
# 02/01/2015
# 2
# 01/07/2011
# 1
# 06/27/2013
# 1
# 12/05/2012
# 2
# 04/04/2012
# 2
# 08/03/2012
# 1
# 01/01/2006
# 2
# 01/01/2010
# 2
# 01/01/2000
# 2
# 01/01/2000
# 2
# 01/01/2001
# 2
# 01/01/2002
# 2
# 01/01/2004
# 2
# 01/01/1994
# 2
# 01/01/1994
# 2
# 01/01/1996
# 1
# 01/01/1998
# 2
# 01/01/1989
# 2
# 01/01/1993
# 2
# 01/01/1994
# 2
# 01/01/1994
# 1
# 09/27/2011
# 1
# 01/01/1995
# https://tzlatko.bandcamp.com
# 3
# 01/06/2013
# https://quadnine.bandcamp.com
# 3
# 04/23/2013
# https://smalltowngypsymassacre.bandcamp.com
# 3
# 06/29/2011
# https://goldsmithrocks.bandcamp.com
# 3
# 09/23/2016
# https://jasoncovenant.bandcamp.com
# 3
# 09/04/2011
# https://nudler.bandcamp.com
# 2
# 12/02/2018
# 2
# 12/04/2017
# 2
# 12/24/2014
# 2
# 12/20/2013
# 2
# 12/24/2012
# 2
# 12/24/2010
# 2
# 12/24/2009
# 2
# 12/24/2008
# https://theepsionicassembly.bandcamp.com
# 2
# 08/08/2015
# 2
# 07/24/2013
# 2
# 01/26/2013
# 2
# 10/23/2012
# 2
# 05/23/2012
# 2
# 07/26/2012
# 2
# 09/23/2011
# 2
# 09/30/2012
# 2
# 06/30/2011
# https://kraytwinsmusic.bandcamp.com
# 3
# 05/07/2011
# https://adamjasanttu.bandcamp.com
# 3
# 07/05/2011
# https://thelovejunkies.bandcamp.com
# 3
# 07/07/2017
# https://sombrerotwist.bandcamp.com
# 3
# 06/25/2011
# https://revivalhymns.bandcamp.com
# 3
# 01/07/2014
# https://pietrocrespi.bandcamp.com
# 2
# 12/23/2011
# 2
# 09/05/2011
# 2
# 08/01/2010
# 2
# 12/31/2009
# https://nightvisionusa.bandcamp.com
# 3
# 07/03/2013
# https://project1804.bandcamp.com
# 3
# 06/23/2011
# https://atpdmv.bandcamp.com
# 3
# 11/11/2012
# https://bgwhyte.bandcamp.com
# 3
# 01/21/2019
# https://starfoxx.bandcamp.com
# 2
# 08/15/2012
# 2
# 03/27/2012
# 2
# 06/04/2011
# https://honeydisco.bandcamp.com
# 3
# 07/01/2011
# https://calebkennedy.bandcamp.com
# 3
# 07/01/2011
# https://constellationrising.bandcamp.com
# 3
# 01/06/2011
# https://thedacios.bandcamp.com
# 3
# 08/01/2009
# https://battlefingers.bandcamp.com
# 3
# 06/29/2011
# https://dtb69.bandcamp.com
# 1
# 06/16/2016
# 1
# 11/06/2011
# 1
# 10/28/2011
# 1
# 09/30/2011
# 1
# 06/06/2010
# 1
# 03/22/2010
# 1
# 01/02/2010
# 1
# 01/02/2010
# https://theheavyfeathers.bandcamp.com
# 3
# 05/27/2011
# https://machinemodel.bandcamp.com
# 1
# 05/01/2011
# 1
# 05/01/2011
# 1
# 05/01/2011
# 1
# 05/01/2011
# https://totaldevastation.bandcamp.com
# 3
# 06/06/2012
# https://theforgottenjam.bandcamp.com
# 3
# 08/21/2017
# https://gusher.bandcamp.com
# 2
# 09/28/2013
# 2
# 09/28/2013
# 2
# 08/07/2012
# 2
# 11/12/2011
# 2
# 06/18/2011
# https://namesinnumbers.bandcamp.com
# 3
# 10/30/2011
# https://laespecialidaddelacasa.bandcamp.com
# 2
# 04/15/2012
# 2
# 06/10/2010
# https://bobbyblue.bandcamp.com
# 3
# 05/29/2018
# https://bengiesbrecht.bandcamp.com
# 3
# 03/03/2012
# https://theauxheard.bandcamp.com
# 1
# 07/01/2011
# 1
# 07/01/2011
# https://thewalkonby.bandcamp.com
# 3
# 04/08/2011
# https://thestorageunit.bandcamp.com
# 3
# 03/29/2012
# https://cutpurseempire.bandcamp.com
# 3
# 11/21/2012
# https://gersploosh.bandcamp.com
# 1
# 07/16/2011
# 1
# 06/28/2011
# https://diamonddancer.bandcamp.com
# 2
# 10/11/2011
# 2
# 07/26/2011
# https://caseracer.bandcamp.com
# 2
# 10/22/2013
# 2
# 02/12/2013
# 2
# 02/02/2012
# https://saturn-return.bandcamp.com
# 3
# 11/01/2011
# https://dmorpheus.bandcamp.com
# 3
# 06/29/2011
# https://raveneye1.bandcamp.com
# 3
# 06/17/2011
# https://zinniablue.bandcamp.com
# 1
# N/A
# 1
# N/A
# https://forwhatitsworthny.bandcamp.com
# 3
# 11/23/2018
# https://brittanordica.bandcamp.com
# 3
# 06/27/2011
# https://shiningwizado.bandcamp.com
# 3
# 06/13/2012
# https://gerardpb.bandcamp.com
# 3
# 04/16/2019
# https://patch-werk.bandcamp.com
# 3
# 01/28/2011
# https://thegreatoceandivide.bandcamp.com
# 3
# 03/27/2014
# https://hushhousebandcamp.bandcamp.com
# 3
# 05/04/2012
# https://thebarrens.bandcamp.com
# 3
# 04/30/2018
# https://26thletter.bandcamp.com
# 3
# 06/28/2011
# https://animalgames.bandcamp.com
# 3
# 01/11/2016
# https://nicolasmateo.bandcamp.com
# 2
# 05/25/2018
# 2
# 06/10/2016
# 2
# 02/27/2014
# 2
# 12/02/2011
# 2
# 02/02/2010
# 2
# 02/25/2008
# https://dprofoundinc.bandcamp.com
# 3
# 06/30/2011
# https://gabmusic.bandcamp.com
# 3
# 06/01/2011
# https://supercommuter.net
# 2
# 06/01/2018
# 2
# 08/16/2011
# 2
# 08/12/2012
# 2
# 04/03/2012
# 2
# 07/21/2009
# https://thehecticglow.bandcamp.com
# 3
# 06/29/2011
# https://rodellosmachine.bandcamp.com
# 3
# 07/07/2016
# https://fauxhound.bandcamp.com
# 3
# 08/17/2012
# https://makeyourselfrecords.bandcamp.com
# 3
# 12/13/2011
# https://shimon.bandcamp.com
# 3
# 02/14/2015
# https://lidz.bandcamp.com
# 2
# 07/14/2010
# 2
# 07/07/2009
# https://quailbones.bandcamp.com
# 3
# 02/24/2017
# https://heavychandler.bandcamp.com
# 3
# 05/01/2011
# https://convertidosdesdelarabia.bandcamp.com
# 3
# 07/27/2010
# https://cianomaes.bandcamp.com
# 3
# 03/26/2018
# https://tristanomeara.bandcamp.com
# 2
# 01/01/2016
# 2
# 06/24/2013
# 2
# 06/30/2011
# 2
# 08/01/2012
# 2
# 01/01/2009
# https://sbht.bandcamp.com
# 1
# N/A
# 2
# 02/28/2012
# 1
# 05/12/2011
# https://heraclitusakimbo.bandcamp.com
# 2
# 02/20/2019
# 2
# 09/07/2018
# 2
# 07/18/2018
# 2
# 04/13/2018
# 2
# 02/27/2018
# 2
# 07/01/2017
# 2
# 06/29/2017
# 2
# 10/02/2016
# 2
# 08/07/2016
# 2
# 05/28/2016
# 2
# 12/22/2015
# 2
# 06/01/2015
# 2
# 02/05/2015
# 2
# 12/01/2008
# https://phatballz.bandcamp.com
# 2
# 12/10/2011
# 2
# 12/10/2011
# 2
# 12/10/2011
# 2
# 06/28/2011
# https://dofonodeomulu.bandcamp.com
# 3
# 07/01/2011
# https://mindinscription.bandcamp.com
# 3
# 09/16/2004
# https://1b1bmixtape.bandcamp.com
# 3
# 04/04/2013
# https://secondoffense.bandcamp.com
# 3
# 08/11/2008
# https://fitz76.bandcamp.com
# 3
# 04/29/2012
# https://krom1.bandcamp.com
# 3
# 03/26/2012
# https://localmusic101.bandcamp.com
# 3
# 01/20/2012
# https://maradonaphl.bandcamp.com
# 3
# 06/27/2011
# https://problemsolver.bandcamp.com
# 3
# 08/01/2011
# https://letsquestcollective.bandcamp.com
# 2
# 12/30/2011
# 2
# 02/06/2012
# 2
# 02/20/2012
# 2
# 01/17/2012
# 2
# 02/10/2012
# 2
# 11/24/2011
# 2
# 12/01/2011
# 2
# 08/30/2011
# 2
# 01/11/2012
# 2
# 03/06/2012
# 2
# 11/30/2011
# 2
# 06/15/2011
# 2
# 04/19/2012
# https://allaboutabubble5.bandcamp.com
# 1
# 07/28/2011
# 1
# 07/28/2011
# https://mikemakesamess.bandcamp.com
# 3
# 03/22/2014
# https://catstalksbird.bandcamp.com
# 3
# 05/29/2011
# https://gravemistakerecords.bandcamp.com
# 2
# 01/11/2017
# 2
# 12/06/2016
# 2
# 10/07/2016
# 2
# 08/12/2016
# 2
# 08/19/2016
# 2
# 07/15/2016
# 2
# 04/08/2016
# 2
# 03/23/2016
# 2
# 10/06/2015
# 2
# 04/21/2015
# 2
# 01/29/2015
# 2
# 06/17/2014
# 2
# 01/29/2015
# 2
# 09/23/2014
# 2
# 09/23/2014
# 2
# 06/17/2014
# 2
# 05/23/2014
# 2
# 02/11/2014
# 2
# 11/06/2013
# 2
# 07/17/2013
# 2
# 07/09/2013
# 2
# 07/09/2013
# 2
# 07/17/2013
# 2
# 05/14/2013
# 2
# 04/09/2013
# 2
# 04/09/2013
# 2
# 04/09/2013
# 2
# 02/26/2013
# 2
# 02/26/2013
# 2
# 08/21/2012
# 2
# 05/17/2011
# 2
# 04/17/2012
# 2
# 04/17/2012
# 2
# 02/29/2012
# 2
# 02/29/2012
# 2
# 09/13/2011
# 2
# 09/13/2011
# 2
# 04/22/2011
# 2
# 04/04/2006
# 2
# 04/29/2011
# 2
# 01/26/2011
# 2
# 04/04/2011
# 2
# 11/17/2014
# 2
# 04/01/2010
# 2
# 03/16/2010
# 2
# 11/17/2009
# 2
# 01/22/2010
# 2
# 06/03/2009
# 2
# 06/03/2009
# 2
# 07/03/2009
# 2
# 04/06/2009
# 2
# 03/06/2009
# 2
# 03/06/2009
# 2
# 09/26/2008
# 2
# 08/01/2008
# 2
# 03/28/2008
# 2
# 01/08/2008
# 2
# 03/06/2009
# 2
# 05/22/2007
# 2
# 06/01/2007
# 2
# 08/01/2006
# 2
# 12/15/2005
# 2
# 09/01/2005
# 2
# 06/01/2005
# 2
# 09/01/2005
# 2
# 04/01/2004
# 2
# 01/01/2004
# 2
# 01/01/2003
# https://methamphenomenal.bandcamp.com
# 3
# 06/28/2011
# https://davebwithadultratesavs.bandcamp.com
# 3
# 06/28/2011
# https://zayahodges.bandcamp.com
# 1
# 10/11/2011
# 1
# 10/11/2011
# 1
# 06/29/2011
# https://reliefrecordings.bandcamp.com
# 3
# 06/29/2011
# https://etaby.bandcamp.com
# 3
# 02/14/2014
# https://roguemartian.bandcamp.com
# 2
# 04/20/2011
# 2
# 03/05/2011
# https://3oobeatzz.bandcamp.com
# 1
# N/A
# 1
# N/A
# 1
# N/A
# 1
# N/A
# 1
# N/A
# 1
# 07/13/2011
# 1
# 07/07/2011
# 2
# 07/07/2011
# 1
# 07/07/2011
# https://wehrwolforder.bandcamp.com
# 2
# 07/02/2011
# 2
# 06/20/2011
# https://l3dse7endubstep.bandcamp.com
# 3
# 07/01/2011
# https://syntheticcolours.bandcamp.com
# 3
# 03/25/2014
# https://moscowtraffic.bandcamp.com
# 3
# 06/19/2011
# https://disparagement.bandcamp.com
# 3
# 09/13/2009
# https://thejameshateclub.bandcamp.com
# 3
# 06/28/2011
# https://ourguys.bandcamp.com
# 3
# 07/14/2012
# https://jesusclanmovement.bandcamp.com
# 3
# 08/15/2014
# https://theshortwaves.bandcamp.com
# 3
# 06/29/2011
# https://colossaljr.bandcamp.com
# 3
# 08/24/2011
# https://sansserif.bandcamp.com
# 2
# 12/03/2011
# 2
# 06/26/2011
# https://awaldo.bandcamp.com
# 1
# 12/29/2014
# 2
# 12/25/2013
# 2
# 07/11/2012
# https://xcadencex.bandcamp.com
# 3
# 02/13/2010
# https://vosmefallastehc.bandcamp.com
# 3
# 11/12/2010
# https://mierdaster.bandcamp.com
# 3
# 09/20/2012
# https://pokadot.bandcamp.com
# 3
# 06/01/2011
# https://meiohara.bandcamp.com
# 2
# 11/26/2018
# 1
# 10/19/2018
# 1
# 01/21/2018
# 2
# 08/18/2017
# 1
# 02/28/2017
# 1
# 08/18/2015
# 1
# 06/30/2014
# 2
# 12/05/2013
# 2
# 01/27/2013
# 1
# 10/24/2013
# 2
# 01/25/2013
# https://diamondbreaker.bandcamp.com
# 3
# 09/16/2013
# https://justmaine.bandcamp.com
# 3
# N/A
# https://geeandjamma.bandcamp.com
# 3
# 06/24/2012
# https://rivalriesarefun.bandcamp.com
# 2
# 04/29/2015
# 2
# 11/27/2012
# 1
# 11/01/2012
# 2
# 06/25/2011
# https://voodateach.bandcamp.com
# 3
# 01/15/2014
# https://theblackheartthrobs.bandcamp.com
# 3
# 07/26/2017
# https://royala.bandcamp.com
# 3
# 10/31/2009
# https://symphonyintheglen.bandcamp.com
# 3
# 06/02/2011
# https://beleza.bandcamp.com
# 3
# 02/05/2016
# https://kwvmusic.bandcamp.com
# 3
# 06/29/2011
# https://loudandquiet.bandcamp.com
# 3
# 01/05/2010
# https://omarmusisko.bandcamp.com
# 3
# 12/19/2010
# https://thesummervilles.bandcamp.com
# 3
# 03/12/2018
# https://mruseta.bandcamp.com
# 3
# 11/17/2009
# https://wishpig.bandcamp.com
# 3
# 09/04/2009
# https://tkclowell.bandcamp.com
# 3
# 06/06/2006
# https://shashaheed.bandcamp.com
# 3
# 06/18/2012
# https://michaeljruhland.bandcamp.com
# 3
# 06/28/2011
# https://bangbangboom.bandcamp.com
# 3
# 05/19/2012
# https://allmyfriendsaz.bandcamp.com
# 3
# 07/31/2011
# https://danterising.bandcamp.com
# 3
# 06/28/2011
# https://lunavroum.bandcamp.com
# 2
# 12/01/2010
# 2
# 08/12/2009
# https://3trousers.bandcamp.com
# 3
# 04/01/2019
# https://dementedpromotions.bandcamp.com
# 2
# 06/18/2011
# 2
# 07/15/2011
# 1
# 07/02/2011
# 1
# 07/10/2011
# 1
# 07/17/2011
# 1
# 07/19/2011
# 1
# 07/21/2011
# 1
# 07/23/2011
# 1
# 08/02/2011
# 1
# 06/18/2011
# https://perditions.bandcamp.com
# 3
# 07/04/2011
# https://greaterthanmusicgroup.bandcamp.com
# 3
# 06/14/2011
# https://jenniferrannells.bandcamp.com
# 3
# 11/11/2002
# https://electricservice1.bandcamp.com
# 3
# 01/13/2011
# https://massimodemajo.bandcamp.com
# 3
# 12/19/2000
# https://bitchcraft.bandcamp.com
# 2
# 07/20/2011
# 2
# 07/03/2011
# https://thefleshfullofblacksand.com
# 1
# 06/28/2019
# 2
# 06/11/2019
# 2
# 05/08/2019
# 2
# 04/10/2019
# 2
# 04/01/2019
# 2
# 03/21/2019
# 1
# 03/15/2019
# 2
# 03/09/2019
# 1
# 03/08/2019
# 1
# 03/06/2019
# 2
# 03/03/2019
# 2
# 03/03/2019
# 2
# 02/07/2019
# 2
# 01/21/2019
# 2
# 01/18/2019
# 2
# 01/12/2019
# 2
# 01/01/2019
# 2
# 12/15/2018
# 1
# 12/14/2018
# 1
# 12/10/2018
# 1
# 11/27/2018
# 1
# 11/24/2018
# 1
# 11/22/2018
# 1
# 11/10/2018
# 2
# 10/28/2018
# 1
# 10/25/2018
# 2
# 10/21/2018
# 1
# 10/05/2018
# 1
# 09/04/2018
# 2
# 09/09/2018
# 1
# 08/23/2018
# 1
# 08/22/2018
# 2
# 08/22/2018
# 2
# 08/24/2018
# 1
# 08/14/2018
# 2
# 08/12/2018
# 1
# 07/24/2018
# 2
# 06/21/2018
# 2
# 06/07/2018
# 1
# 05/19/2018
# 1
# 05/14/2018
# 2
# 05/11/2018
# 2
# 05/11/2018
# 2
# 05/09/2018
# 2
# 05/01/2018
# 2
# 04/11/2018
# 1
# 04/08/2018
# 1
# 03/27/2018
# 2
# 02/27/2018
# 2
# 08/02/2017
# 2
# 06/18/2017
# 2
# 04/05/2017
# 2
# 02/03/2017
# 2
# 12/08/2016
# 2
# 11/17/2016
# 2
# 07/16/2016
# 2
# 05/17/2016
# 2
# 03/16/2016
# 2
# 02/10/2016
# 2
# 01/14/2016
# 2
# 07/17/2015
# 2
# 12/18/2014
# 2
# 12/01/2014
# 2
# 07/10/2014
# 2
# 05/31/2013
# 2
# 05/05/2013
# 2
# 10/07/2012
# 2
# 08/31/2012
# 2
# 07/22/2012
# 2
# 06/11/2012
# 2
# 05/14/2012
# 2
# 03/09/2012
# 2
# 06/28/2011
# https://theimaginarywar.bandcamp.com
# 3
# 05/20/2016
# https://birdsick.bandcamp.com
# 3
# 06/27/2011
# https://joeadrift.bandcamp.com
# 3
# 08/14/2013
# https://theillspeciez.bandcamp.com
# 3
# 06/22/2011
# https://wizard.bandcamp.com
# 3
# 01/20/2012
# https://lxmusic.bandcamp.com
# 3
# 04/17/2014
# https://boyvsghost.bandcamp.com
# 2
# 02/13/2018
# 2
# 07/23/2017
# 2
# 01/09/2017
# 1
# 07/31/2015
# 1
# 06/12/2015
# 2
# 12/16/2014
# 1
# 07/04/2014
# 1
# 06/30/2014
# 2
# 08/27/2012
# 2
# 01/04/2011
# 2
# 01/17/2007
# https://theheights.bandcamp.com
# 3
# 07/09/2013
# https://mavisbeaconmusic.bandcamp.com
# 3
# 10/21/2011
# https://grouse.bandcamp.com
# 2
# 04/12/2019
# 2
# 05/30/2016
# 2
# 04/09/2014
# 2
# 11/21/2012
# 2
# 04/28/2005
# https://thecmz.bandcamp.com
# 3
# 07/05/2011
# https://mutzik.bandcamp.com
# 2
# 01/02/2014
# 2
# 12/01/2012
# https://wallywinks.bandcamp.com
# 3
# 06/28/2011
# https://sadecetm.bandcamp.com
# 3
# 10/07/2011
# https://the-morning-of.bandcamp.com
# 3
# 06/28/2011
# https://tijerina.bandcamp.com
# 3
# 11/08/2010
# https://throughthegrapevine.bandcamp.com
# 3
# 07/01/2011
# https://ktdugan.bandcamp.com
# 3
# 04/14/2019
# https://poeticminds.bandcamp.com
# 3
# 02/08/2014
# https://greatwhitebuffalobuffalo.bandcamp.com
# 2
# 09/09/2011
# 2
# 07/04/2011
# https://eviltwinrecords.bandcamp.com
# 2
# 12/12/2018
# 2
# 01/22/2017
# 2
# 06/23/2015
# 2
# 08/11/2013
# 2
# 02/13/2017
# 2
# 08/31/2012
# 2
# 07/07/2012
# 2
# 03/17/2013
# 2
# 11/23/2009
# https://lunik3.bandcamp.com
# 3
# 11/10/2015
# https://alexhaynes.bandcamp.com
# 2
# 02/05/2018
# 2
# 12/22/2014
# 2
# 01/17/2011
# https://greasetrap.bandcamp.com
# 3
# 04/04/1992
# https://kafkaesque.bandcamp.com
# 3
# 01/05/2017
# https://boygirlparty.bandcamp.com
# 3
# 10/10/2014
# https://illusionprospect.bandcamp.com
# 2
# 03/10/2016
# 2
# 01/04/2016
# 2
# 11/13/2015
# 2
# 10/06/2015
# 2
# 06/03/2015
# 2
# 10/01/2013
# 2
# 11/01/2013
# 2
# 02/06/2014
# 2
# 03/08/2012
# 2
# 02/20/2014
# 2
# 06/01/2010
# 2
# 06/15/2008
# 2
# 05/11/2013
# https://atyourexpense.bandcamp.com
# 3
# N/A
# https://halfviolent.bandcamp.com
# 3
# 05/01/2011
# https://probethemind.bandcamp.com
# 1
# 01/06/2002
# 1
# 01/06/2002
# 1
# 01/06/2002
# 2
# 06/01/1999
# https://hollowteeth.bandcamp.com
# 3
# 10/06/2011
# https://bshnorkestra.bandcamp.com
# 3
# 11/18/2016
# https://chrisscott.bandcamp.com
# 3
# 07/23/2011
# https://invisiblemonsters.bandcamp.com
# 2
# 12/13/2016
# 2
# 11/14/2016
# 2
# 04/01/2012
# 2
# 09/26/2011
# 2
# 06/28/2011
# 2
# 08/22/2010
# 2
# 10/25/2009
# 2
# 01/28/2009
# 2
# 04/06/2007
# https://spektrah.bandcamp.com
# 3
# 11/16/2011
# https://laurenmarie.bandcamp.com
# 3
# 08/01/2011
# https://djglauben.bandcamp.com
# 3
# 10/01/2011
# https://youlovepaper.bandcamp.com
# 1
# N/A
# 1
# 07/16/2012
# 1
# 07/16/2012
# 1
# 08/28/2011
# 1
# 07/16/2012
# 2
# 12/03/2009
# 2
# 07/21/2012
# 1
# 07/19/2011
# 1
# 07/16/2012
# 1
# 09/30/2011
# 1
# 06/27/2011
# 1
# 11/16/2011
# 1
# 07/21/2012
# 1
# 07/17/2012
# 1
# 07/16/2012
# 1
# 11/30/2011
# 1
# 10/07/2011
# 1
# 06/26/2011
# 1
# 05/01/2011
# 1
# 07/11/2009
# 1
# 12/31/2008
# 1
# 05/28/2008
# 1
# 07/07/2007
# 1
# 07/07/1979
# https://sopastel.bandcamp.com
# 3
# 10/16/2013
# https://misselisabeth.bandcamp.com
# 3
# 08/02/2011
# https://insideswitch.bandcamp.com
# 3
# 08/12/2012
# https://baekelandt.bandcamp.com
# 3
# 02/23/2012
# https://west-section.bandcamp.com
# 3
# 06/28/2011
# https://tomhanson.bandcamp.com
# 2
# 05/09/2018
# 2
# 06/01/2000
# 2
# 11/01/2007
# 2
# 08/01/2011
# https://randolphgroup.bandcamp.com
# 3
# 06/13/2011
# https://killtheclient.bandcamp.com
# 3
# 10/26/2010
# https://magpieinstinct.bandcamp.com
# 2
# 02/19/2014
# 2
# 04/07/2012
# 2
# 02/29/2012
# https://granvillegranville.bandcamp.com
# 3
# 06/11/2012
# https://fairfaxak.bandcamp.com
# 3
# 09/15/2016
# https://barrowstheband.bandcamp.com
# 3
# 05/26/2017
# https://merkywatersmusic.bandcamp.com
# 2
# 12/20/2014
# 2
# 12/15/2013
# 2
# 12/11/2013
# 2
# 12/15/2012
# 2
# 12/15/2012
# 2
# 07/01/2011
# https://badshoesrecords.bandcamp.com
# 3
# 11/01/2011
# https://picniconadirigible.bandcamp.com
# 3
# N/A
# https://astrokid.bandcamp.com
# 2
# 04/15/2014
# 2
# 07/23/2013
# 2
# 06/24/2013
# 2
# 04/20/2013
# 2
# 02/29/2012
# 2
# 03/22/2012
# 2
# 06/28/2011
# https://damonandnaomi.bandcamp.com
# 2
# 02/14/2019
# 1
# 12/02/2016
# 2
# 02/14/2015
# 2
# 05/17/2011
# 2
# 09/20/2017
# 2
# 09/25/2007
# 2
# 02/14/2005
# 2
# 04/23/2002
# 2
# 04/23/2002
# 2
# 09/05/2000
# 2
# 04/07/1998
# 2
# 04/20/2013
# 2
# 09/22/1992
# 2
# 07/20/1991
# https://mrcrowseph.bandcamp.com
# 3
# 07/04/2011
# https://burriedinthesand.bandcamp.com
# 3
# 06/29/2011
# https://breakfastjumpers.bandcamp.com
# 2
# 07/17/2015
# 2
# 01/07/2015
# 2
# 07/24/2006
# 2
# 05/18/2012
# 2
# 05/31/2011
# 2
# 11/05/2011
# 2
# 10/15/2010
# 2
# 07/31/2014
# 2
# 07/14/2014
# 2
# 07/11/2014
# 2
# 07/05/2014
# 2
# 06/28/2014
# 2
# 04/14/2014
# 2
# 09/18/2013
# 2
# 07/22/2013
# 2
# 08/30/2013
# 2
# 07/15/2013
# 2
# 07/08/2013
# 2
# 07/05/2013
# 2
# 07/04/2013
# 2
# 07/24/2012
# 2
# 03/15/2013
# 2
# 06/21/2013
# 2
# 09/20/2013
# 2
# 12/10/2013
# 2
# 03/19/2012
# 2
# 06/19/2012
# 2
# 09/21/2012
# 2
# 12/10/2012
# https://opposide.bandcamp.com
# 2
# 05/21/2019
# 2
# 05/02/2019
# 2
# 02/20/2019
# 2
# 01/14/2019
# 2
# 09/12/2018
# 2
# 04/18/2018
# 2
# 09/27/2017
# 2
# 06/22/2017
# 2
# 04/13/2017
# 2
# 03/24/2017
# 2
# 01/21/2017
# 2
# 12/21/2016
# 2
# 11/16/2016
# 2
# 04/20/2016
# 2
# 11/09/2015
# 2
# 03/27/2015
# 2
# 08/22/2014
# 2
# 12/21/2012
# 2
# 02/17/2011
# 2
# 10/01/2008
# 2
# 01/31/2007
# 2
# 08/12/2012
# 2
# 05/26/2009
# 2
# 03/08/2012
# 2
# 03/08/2012
# 2
# 03/08/2012
# 2
# 03/29/2012
# https://lutomysl.bandcamp.com
# 3
# 12/14/2018
# https://logicdabeatman.bandcamp.com
# 2
# 04/09/2013
# 2
# 10/22/2012
# 2
# 06/28/2011
# https://noizeofficial.bandcamp.com
# 3
# 06/28/2011
# https://lyva.bandcamp.com
# 3
# 06/29/2011
# https://sunfishmoonlight.bandcamp.com
# 3
# 01/27/2019
# https://sharksandminnows.bandcamp.com
# 3
# 07/10/2011
# https://xiumusic.bandcamp.com
# 2
# 07/18/2014
# 1
# 06/01/2014
# 2
# 12/10/2013
# 1
# 03/02/2013
# 2
# 02/09/2013
# 2
# 10/12/2012
# https://wordsofjoshua.bandcamp.com
# 3
# 06/28/2011
# https://brandoncrookz.bandcamp.com
# 3
# 07/04/2011
# https://hermanosturdera.bandcamp.com
# 3
# 06/29/2011
# https://muchachobeat.bandcamp.com
# 3
# 06/28/2011
# https://dakreek.bandcamp.com
# 1
# 10/21/2014
# 1
# 04/25/2014
# 1
# 04/23/2014
# 1
# 12/10/2012
# 2
# 11/23/2012
# 1
# 11/02/2012
# 2
# 06/28/2011
# 1
# 02/01/2012
# 1
# 01/25/2012
# https://thesaintjamessociety.bandcamp.com
# 1
# 02/12/2012
# 1
# 11/01/2011
# 1
# 01/11/2011
# https://gilbertgrape.bandcamp.com
# 3
# 01/01/2017
# https://dimebagjonnys.bandcamp.com
# 3
# 06/28/2011
# https://nathanaaron.bandcamp.com
# 3
# 05/12/2011
# https://diedofcrash.bandcamp.com
# 3
# 06/26/2011
# https://blastmasterbaker.bandcamp.com
# 1
# 02/18/2016
# 2
# 04/01/2013
# https://disposalunit.bandcamp.com
# 3
# 06/28/2011
# https://queenpbyfk.bandcamp.com
# 3
# 06/28/2011
# https://cuetigers.bandcamp.com
# 1
# 06/27/2017
# 1
# 10/22/2016
# 2
# 07/15/2013
# 2
# 01/08/2012
# 2
# 06/29/2011
# 2
# 01/02/2012
# 2
# 12/20/2011
# https://greytwhytehype.bandcamp.com
# 3
# 07/01/2012
# https://xtraordinaryann.bandcamp.com
# 3
# 06/28/2011
# https://blaxter.bandcamp.com
# 3
# 07/15/2012
# https://swearjarfl.bandcamp.com
# 3
# 06/01/2011
# https://akaj.bandcamp.com
# 3
# 06/25/2011
# https://benjaminduboc.bandcamp.com
# 3
# 04/24/2013
# https://lesdisquesflow.bandcamp.com
# 3
# 01/12/2010
# https://projectvaygar.bandcamp.com
# 3
# 06/12/2008
# https://david5.bandcamp.com
# 3
# 06/28/2011
# https://friendsagain.bandcamp.com
# 3
# 07/15/2011
# https://artofabsence.bandcamp.com
# 3
# 05/25/2010
# https://cykeldoden.bandcamp.com
# 1
# 04/27/2012
# 2
# 06/28/2011
# https://stephanmikes.bandcamp.com
# 2
# 01/17/2018
# 1
# 01/17/2018
# 1
# 01/09/2018
# 1
# 08/22/2013
# 1
# 07/16/2011
# 1
# 07/07/2011
# 2
# 10/11/2009
# 2
# 06/02/2002
# 1
# 12/12/1994
# https://theowlparliament.bandcamp.com
# 3
# 12/05/2014
# https://themilliondollarpunkband.bandcamp.com
# 2
# 05/09/2014
# 2
# 06/09/2014
# https://tunguskamammoth.bandcamp.com
# 3
# 05/11/2018
# https://steviescott.bandcamp.com
# 3
# 04/04/2011
# https://lhfreaks.bandcamp.com
# 3
# 06/28/2011
# https://elementsraw.bandcamp.com
# 3
# 04/23/2012
# https://diogocorreia.bandcamp.com
# 3
# 06/13/2012
# https://unrulydogs.bandcamp.com
# 3
# 06/03/2012
# https://carlpike.bandcamp.com
# 3
# 06/16/2009
# https://bryanlaurier.bandcamp.com
# 3
# 06/26/2012
# https://originalkainekdp91.bandcamp.com
# 3
# 11/09/2012
# https://friendshipbraceletclub.bandcamp.com
# 3
# 07/12/2011
# https://teknikatx.bandcamp.com
# 2
# 03/12/2019
# 2
# 09/10/2018
# 2
# 12/12/2017
# 2
# 08/02/2017
# 2
# 04/02/2017
# 2
# 03/02/2016
# 2
# 04/20/2014
# 2
# 02/12/2013
# https://carlworricker.bandcamp.com
# 3
# 06/22/2011
# https://metzgore.bandcamp.com
# 3
# 09/04/2010
# https://kyddoft.bandcamp.com
# 3
# 06/01/2007
# https://thebungalows.bandcamp.com
# 2
# 03/22/2019
# 1
# 02/06/2019
# 1
# 12/14/2018
# 1
# 09/01/2015
# 1
# 12/14/2014
# 2
# 07/08/2011
# 2
# 07/07/2009
# 2
# 07/07/2008
# 2
# 07/07/2007
# https://foreigns.bandcamp.com
# 3
# 05/24/2017
# https://mannyoakley.bandcamp.com
# 3
# N/A
# https://marcleblanc.bandcamp.com
# 3
# N/A
# https://carbonbycarbon.bandcamp.com
# 2
# 11/01/2017
# 2
# 11/01/2017
# 2
# 11/01/2017
# https://elrajo.bandcamp.com
# 3
# 06/28/2011
# https://rushingwaters.bandcamp.com
# 3
# 06/30/2011
# https://contranyc.bandcamp.com
# 3
# 11/07/2011
# https://myelinsheaths.bandcamp.com
# 2
# 06/28/2011
# 2
# 10/10/2010
# 2
# 10/01/2010
# 2
# 01/01/2010
# 2
# 01/01/2010
# 2
# 06/01/2008
# https://bearz.bandcamp.com
# 2
# 11/11/2012
# 2
# 07/25/2012
# 2
# 11/02/2011
# 2
# 09/23/2011
# 2
# 07/03/2011
# https://duosolar.bandcamp.com
# 3
# 06/28/2011
# https://ricarsj.bandcamp.com
# 3
# 04/07/2011
# https://cortisol.bandcamp.com
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 2
# 04/21/2015
# https://52skidoo.bandcamp.com
# 3
# 01/04/2011
# https://steeelwoool.bandcamp.com
# 3
# 07/11/2011
# https://lifesizemaps.bandcamp.com
# 1
# 09/27/2017
# 2
# 06/18/2015
# 2
# 06/01/2015
# 2
# 04/07/2015
# https://catpeoplerecords.bandcamp.com
# 2
# 07/14/2013
# 2
# 06/06/2012
# 2
# 12/01/2009
# 2
# 07/28/2011
# 2
# 08/01/2009
# 2
# 08/01/2009
# 2
# 12/01/2010
# 2
# 03/01/2016
# 2
# 04/12/2013
# https://needlessghost.bandcamp.com
# 3
# 01/12/2019
# https://whichcraft.bandcamp.com
# 3
# 01/13/2018
# https://birdsflysouth.bandcamp.com
# 1
# 08/25/2011
# 1
# 08/13/2011
# 1
# 07/26/2011
# 1
# 07/27/2011
# 1
# 07/12/2011
# 1
# 07/12/2011
# 1
# 07/13/2011
# https://helgijonsson.bandcamp.com
# 3
# 03/15/2019
# https://badattitude.bandcamp.com
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# 1
# 06/28/2011
# https://billdonald.bandcamp.com
# 3
# 07/08/2011
# https://robertvandeven.bandcamp.com
# 1
# 12/09/2017
# 1
# 02/22/2015
# 1
# 05/09/1995
# 1
# 11/12/2015
# 1
# 03/31/2015
# 1
# 02/22/2015
# 1
# 05/09/2014
# 1
# 11/02/2015
# 1
# 10/25/2015
# 1
# 05/09/1995
# https://escapetonight.bandcamp.com
# 3
# 09/30/2011
# https://balmora.bandcamp.com
# 3
# 06/25/2011
# https://wink.bandcamp.com
# 3
# 06/30/2011
# https://sebastianwaldejer.bandcamp.com
# 3
# 07/01/2011
# https://tdota.bandcamp.com
# 2
# 11/06/2012
# 1
# 06/12/2012
# 2
# 08/23/2011
# 2
# 07/12/2011
# 2
# 05/25/2010
# https://iblametheparentsrecords.bandcamp.com
# 2
# 01/01/2011
# 2
# 03/01/2009
# 2
# 07/18/2011
# 2
# 09/12/2011
# 2
# 06/13/2011
# 2
# 09/19/2011
# 2
# 04/02/2012
# 2
# 01/01/2011
# 2
# 01/01/2012
# 2
# 09/01/2014
# 1
# 08/04/2014
# 2
# 05/12/2014
# 2
# 09/10/2012
# 1
# 08/06/2012
# 2
# 09/05/2011
# 2
# 08/01/2011
# 2
# 01/01/2011
# https://get-wise.bandcamp.com
# 3
# 05/22/2014
# https://carpeaux.bandcamp.com
# 2
# 09/06/2012
# 2
# 09/05/2012
# 2
# 07/27/2012
# 2
# 01/01/2012
# 2
# 09/12/2011
# 2
# 09/28/2011
# 2
# 08/26/2011
# 2
# 07/22/2011
# https://ovazio.bandcamp.com
# 3
# 07/11/2017
# https://cyharp.bandcamp.com
# 3
# 06/28/2011
# https://closure.bandcamp.com
# 3
# 03/03/2011
# https://enfantbastard.bandcamp.com
# 2
# 09/04/2012
# 2
# 07/26/2011
# 2
# 06/11/2011
# 2
# 01/01/2011
# 2
# 01/01/2011
# 2
# 01/01/2010
# https://dinosaurreacharound.bandcamp.com
# 3
# 12/21/2012
# https://adriennemckinney.bandcamp.com
# 3
# 06/28/2011
# https://xenograft.bandcamp.com
# 3
# 05/27/2011
# https://cyborgjeff.bandcamp.com
# 3
# 12/25/2018
# https://portopical.bandcamp.com
# 3
# 06/08/2011
# https://ollabelle.bandcamp.com
# 2
# 12/23/2011
# 2
# 08/16/2011
# 2
# 01/01/2007
# https://kiddleon.bandcamp.com
# 3
# 06/01/2007
# https://diogen.bandcamp.com
# 2
# 11/17/2012
# 2
# 01/01/2008
# 2
# 10/01/2006
# https://musicuploads.bandcamp.com
# 3
# 02/23/2010
# https://origamisound.bandcamp.com
# 2
# 01/13/2017
# 2
# 04/08/2016
# 2
# 11/02/2015
# 2
# 07/20/2015
# 2
# 06/22/2015
# 2
# 04/13/2015
# 2
# 02/16/2015
# 2
# 01/19/2015
# 2
# 12/29/2014
# 2
# 10/27/2014
# 2
# 09/26/2014
# 2
# 08/11/2014
# 2
# 07/07/2014
# 2
# 06/27/2014
# 2
# 06/02/2014
# 2
# 05/23/2014
# 2
# 03/03/2014
# 2
# 12/18/2013
# 2
# 11/21/2013
# 2
# 11/18/2013
# 2
# 07/17/2013
# 2
# 06/21/2013
# 2
# 07/01/2013
# 2
# 01/04/2013
# 2
# 02/01/2013
# 2
# 11/12/2012
# 2
# 12/26/2012
# 2
# 07/13/2012
# 2
# 02/14/2012
# 2
# 03/16/2012
# 2
# 06/01/2012
# 2
# 12/15/2011
# 2
# 11/07/2011
# 2
# 10/01/2011
# 2
# 09/09/2011
# 2
# 08/20/2011
# 2
# 07/28/2011
# 2
# 06/30/2011
# https://ewhitsak.bandcamp.com
# 3
# 06/28/2011
# https://edithfunk.bandcamp.com
# 3
# 07/01/2011
# https://artcaveretta.bandcamp.com
# 3
# 05/10/2019
# https://somoslossalvajes.bandcamp.com
# 2
# 06/10/2012
# 2
# 06/01/2011
# 2
# 05/01/2011
# https://rootspirits.bandcamp.com
# 3
# 05/12/2011
# https://archngl.bandcamp.com
# 2
# 06/02/2015
# 2
# 03/28/2014
# 1
# 01/31/2014
# 2
# 08/28/2013
# 2
# 06/07/2012
# 2
# 08/08/2011
# https://shitweather.bandcamp.com
# 3
# 03/16/2012
# https://r-vextra.bandcamp.com
# 1
# 12/07/2016
# 2
# 03/12/2016
# 1
# 01/03/2015
# 2
# 10/11/2014
# 2
# 08/05/2013
# 1
# 12/01/2012
# 1
# 11/14/2012
# 1
# 10/30/2012
# 1
# 12/08/2012
# 1
# 03/17/2013
# 2
# 06/26/2011
# 2
# 06/28/2012
# 1
# 04/24/2012
# 1
# 04/14/2012
# 1
# 07/02/2012
# 1
# 03/31/2012
# 1
# 04/07/2012
# 1
# 02/09/2012
# 1
# 03/27/2012
# 1
# 08/10/2012
# 1
# 11/17/2013
# https://whatgp.bandcamp.com
# 3
# 10/14/2009
# https://jackalheadedguardofthedead.bandcamp.com
# 2
# 03/22/2014
# 2
# 11/11/2010
# 2
# 10/12/2009
# https://2rainure4vous.bandcamp.com
# 3
# 06/29/2011
# https://alphadeomega.bandcamp.com
# 3
# 06/28/2011
# https://heisterkamp.bandcamp.com
# 3
# 09/03/2010
# https://joshsworkshop.bandcamp.com
# 3
# 07/07/2011
# https://ghostnova.bandcamp.com
# 3
# 01/24/2013
# https://killkilldeathdeath.bandcamp.com
# 3
# 07/02/2012
# https://tonypunk.bandcamp.com
# 2
# 02/01/2013
# 2
# 12/31/2011
# 1
# 09/14/2011
# https://oneup1.bandcamp.com
# 3
# 06/29/2011
# https://aboutfallingct.bandcamp.com
# 3
# 01/01/2012
# https://twooclockcourage.bandcamp.com
# 3
# 04/08/2016
# https://sparx.bandcamp.com
# 3
# 04/03/2011
# https://prayermeeting.bandcamp.com
# 3
# 01/14/1978
# https://hymneandietscheggl.bandcamp.com
# 3
# 06/30/2011
# https://benjaminfinger.bandcamp.com
# 3
# 10/20/2016
# https://huangyulin.bandcamp.com
# 3
# 01/01/2012
# https://daverenz.bandcamp.com
# 3
# 04/14/2019
# https://whosmikeb.bandcamp.com
# 3
# 07/17/2015
# https://boxerrva.bandcamp.com
# 3
# 10/16/2013
# https://rnbmillionaires.bandcamp.com
# 3
# 09/17/2018
# https://spermsnake.bandcamp.com
# 3
# 02/01/2013
# https://jamiebeutel.bandcamp.com
# 2
# 06/29/2011
# 1
# 11/23/2010
# https://oddspace.bandcamp.com
# 3
# 06/16/2011
# https://angelicus.bandcamp.com
# 3
# 07/08/2011
# https://electrichomework.bandcamp.com
# 3
# 06/02/2011
# https://melodypool.bandcamp.com
# 3
# 06/28/2011
# https://handles.bandcamp.com
# 3
# 03/10/2017
# https://voguish.bandcamp.com
# 2
# 08/31/2001
# 2
# 01/31/2001
# https://themoanindove.bandcamp.com
# 3
# 07/07/2011
# https://themgoonz1.bandcamp.com
# 3
# 07/27/2011
# https://mogliarchthetravesty.bandcamp.com
# 3
# 08/03/2011
# https://codesciphers.bandcamp.com
# 3
# 07/27/2017
# https://darksister.bandcamp.com
# 3
# 10/31/2015
# https://calebhyersband.bandcamp.com
# 3
# 09/17/2013
# https://evenlesscn.bandcamp.com
# 3
# 04/03/2012
# https://outtheholsterrecords1.bandcamp.com
# 3
# 06/17/2011
# https://debasers.bandcamp.com
# 3
# 12/20/2014
# https://rickymakesmusic.bandcamp.com
# 3
# 07/29/2011
# https://swornenemys.bandcamp.com
# 3
# 04/23/2015
# https://bigt2.bandcamp.com
# 3
# 06/28/2011
# https://kevindippold.bandcamp.com
# 2
# 01/06/2015
# 1
# 06/27/2011
# 1
# 06/27/2011
# 1
# 06/27/2011
# 1
# 06/27/2011
# 1
# 06/27/2011
# 1
# 06/27/2011
# 1
# N/A
# 1
# 06/27/2011
# https://ghostsanddemons.bandcamp.com
# 2
# 01/13/2012
# 2
# 12/31/2011
# 2
# 06/25/2011
# 2
# 02/01/2011
# https://diastoleysistole.bandcamp.com
# 3
# 01/01/2011
# https://benjaminlast.bandcamp.com
# 3
# 03/12/2011
# https://professorofnoise.bandcamp.com
# 3
# 07/01/2011
# https://contrabandcountryband.bandcamp.com
# 3
# 02/09/2017
# https://seedoflife.bandcamp.com
# 3
# 06/28/2011
# https://revizor.bandcamp.com
# 3
# 06/25/2011
# https://auctioneer.bandcamp.com
# 3
# 02/28/2014
# https://damitamajette.bandcamp.com
# 3
# 05/17/2011
# https://feudalism.bandcamp.com
# 3
# 01/03/2015
# https://mexicangrandprix.bandcamp.com
# 3
# 11/10/2011
# https://modernworld.bandcamp.com
# 3
# 06/27/2011
# https://hangonstchristopher.bandcamp.com
# 3
# 06/04/2011
# https://fleas.bandcamp.com
# 3
# 10/30/2013
# https://thedecidingfactor.bandcamp.com
# 3
# 06/27/2011
# https://itzel.bandcamp.com
# 3
# 01/17/2014
# https://eschirtz.bandcamp.com
# 3
# 06/26/2011
# https://willrikernumber1.bandcamp.com
# 3
# 06/27/2011
# https://icharlan.bandcamp.com
# 2
# 06/14/2015
# 2
# 02/19/2015
# 2
# 07/09/2014
# 1
# 01/01/2014
# 2
# 07/29/2012
# 2
# 08/05/2011
# 2
# 01/05/2011
# https://snacktime.bandcamp.com
# 2
# 03/31/2014
# 2
# 09/23/2013
# 2
# 01/11/2013
# https://vonmengeringhausen.bandcamp.com
# 1
# 07/02/2011
# 1
# 04/02/2011
# 1
# 02/11/2011
# 1
# 09/13/2010
# 1
# 12/21/2009
# https://metsu.bandcamp.com
# 3
# 06/28/2011
# https://chaoticproductions.bandcamp.com
# 3
# 06/28/2011
# https://damnsight.bandcamp.com
# 3
# 03/20/2019
# https://musinautas.bandcamp.com
# 3
# 06/28/2011
# https://tinsparrow.bandcamp.com
# 3
# 10/05/2012
# https://audraporter.bandcamp.com
# 3
# 07/04/2011
# https://agitant1.bandcamp.com
# 2
# 08/27/2012
# 2
# 11/01/2011
# 2
# 06/14/2011
# https://myfictionalband.bandcamp.com
# 3
# 01/01/2011
# https://pobrothers.bandcamp.com
# 3
# 06/26/2017
# https://themgoonz.bandcamp.com
# 3
# 07/27/2011
# https://b-ytymoney.bandcamp.com
# 3
# 07/11/2011
# https://therealrealitycheck.bandcamp.com
# 3
# 12/12/2012
# https://marlonrando.bandcamp.com
# 3
# 06/20/2013
# https://corvusmusic.bandcamp.com
# 3
# 06/28/2011
# https://dollarcoffee.bandcamp.com
# 3
# 08/05/2011
# https://verbal.bandcamp.com
# 3
# 08/14/2017
# https://thefastermores.bandcamp.com
# 3
# 07/01/2011
# https://lasupertron.bandcamp.com
# 3
# 09/05/2011
# https://samsage.bandcamp.com
# 2
# 06/14/2016
# 2
# 11/16/2014
# 2
# 10/13/2014
# 2
# 10/09/2014
# 2
# 01/31/2014
# 2
# 11/17/2012
# 2
# 08/24/2011
# 2
# 07/03/2011
# 2
# 08/12/2012
# 2
# 08/17/2012
# 2
# 08/16/2012
# 2
# 08/16/2012
# 2
# 08/17/2012
# 2
# 08/17/2012
# 2
# 08/17/2012
# 2
# 08/16/2012
# 2
# 08/18/2012
# 2
# 08/13/2012
# 2
# 08/16/2012
# 2
# 08/17/2012
# 2
# 08/18/2012
# 2
# 07/09/2011
# 2
# 12/31/2004
# 2
# 08/13/2012
# 2
# 08/18/2012
# 2
# 08/18/2012
# 2
# 08/17/2012
# 2
# 07/09/2011
# 2
# 12/31/2004
# https://divebomber.bandcamp.com
# 3
# 07/05/2011
# https://oceanzi.bandcamp.com
# 3
# 12/25/2011
# https://bradwalker.bandcamp.com
# 3
# 12/29/2015
# https://callthemediccallthenurse.bandcamp.com
# 3
# 10/15/2011
# https://charlesjenkins.bandcamp.com
# 3
# 03/31/2019
# https://pipebombrecords.bandcamp.com
# 2
# 05/01/2012
# 2
# 07/09/2011
# 1
# 06/28/2011
# https://classicalcircles.bandcamp.com
# 3
# 07/02/2013
# https://thelightiris.bandcamp.com
# 3
# 05/09/2013
# https://theshimmies.bandcamp.com
# 2
# 07/27/2010
# 2
# 06/28/2011
# https://asangata.bandcamp.com
# 2
# 04/23/2013
# 2
# 01/20/2012
# 2
# 06/27/2011
# 2
# 08/17/1945
# https://relaxersystem.bandcamp.com
# 3
# 04/05/2019
# https://onetakeband.bandcamp.com
# 3
# 05/17/2011
# https://hsraurbanmusicgroup.bandcamp.com
# 3
# 06/27/2011
# https://newbeings.bandcamp.com
# 3
# 01/03/2013
# https://matthewakers.bandcamp.com
# 2
# 05/17/2018
# 2
# 06/23/2015
# 2
# 05/28/2015
# 2
# 10/08/2014
# 2
# 09/01/2016
# 2
# 03/25/2014
# 2
# 05/17/2015
# 2
# 02/11/2014
# 2
# 10/01/2013
# 2
# 09/30/2012
# 2
# 09/30/2012
# 2
# 06/29/2011
# 2
# 06/29/2012
# 2
# 04/01/2011
# https://teampegasus.bandcamp.com
# 3
# 10/06/2011
# https://tiemusic.bandcamp.com
# 2
# 09/15/2011
# 2
# 06/07/2011
# https://qualitystrangers.bandcamp.com
# 3
# 04/02/2013
# https://music.thelovelysavages.com
# 2
# 07/26/2013
# 2
# 03/20/2012
# 2
# 05/01/2011
# https://heartpumparts.bandcamp.com
# 2
# 05/10/2014
# 2
# 04/18/2007
# 2
# 11/01/2006
# 2
# 08/01/2006
# 2
# 07/01/2006
# 2
# 12/25/2005
# 2
# 06/28/2005
# 2
# 03/16/2010
# 2
# 01/01/2000
# https://milkaneggs.bandcamp.com
# 3
# 03/08/2017
# https://hojjoshmc.bandcamp.com
# 3
# 11/13/2013
# https://midnightrebellion.bandcamp.com
# 3
# 04/20/2012
# https://fragmentedoceans.bandcamp.com
# 3
# 08/12/2011
# https://eluv.bandcamp.com
# 2
# 08/27/2006
# 2
# 08/29/2004
# https://timmyc.bandcamp.com
# 1
# 12/31/2010
# 1
# 12/31/2010
# https://jimmyhiggins.bandcamp.com
# 3
# 07/07/2011
# https://1951.bandcamp.com
# 3
# 08/27/2015
# https://oaks.bandcamp.com
# 3
# 02/16/2013
# https://zerobluecoat.bandcamp.com
# 3
# 06/04/2012
# https://apaperairplane.bandcamp.com
# 3
# 06/27/2012
# https://newera1.bandcamp.com
# 3
# N/A
# https://alivingsoundtrack.bandcamp.com
# 2
# 03/02/2018
# 2
# 06/25/2011
# 2
# 04/01/2006
# https://longmama.bandcamp.com
# 3
# 02/16/2019
# https://nickstirling.bandcamp.com
# 3
# 06/04/2011
# https://youellswinney.bandcamp.com
# 3
# 07/22/2017
# https://briansalcido.bandcamp.com
# 3
# 06/20/2018
# https://katelynmolgard.bandcamp.com
# 3
# 03/21/2016
# https://xtruenaturex.bandcamp.com
# 3
# 04/04/2011
# https://yesiambigrick.bandcamp.com
# 3
# 02/23/2015
# https://dreamcloudmusic.bandcamp.com
# 3
# 06/27/2011
# https://spliffbeats.bandcamp.com
# 3
# 04/25/2014
# https://borkscolio.bandcamp.com
# 3
# 06/24/2011
# https://groovebuggy.bandcamp.com
# 3
# 06/24/2012
# https://illusionofsilence.bandcamp.com
# 3
# 10/10/2009
# https://virtue.bandcamp.com
# 3
# 11/10/2011
# https://ahomeforpatterns.bandcamp.com
# 3
# 03/18/2016
# https://okwerdz.bandcamp.com
# 3
# 04/17/2014
# https://thelonius.bandcamp.com
# 1
# 12/02/2016
# 1
# 02/24/2015
# 2
# 02/14/2015
# 1
# 02/12/2015
# 1
# 11/21/2014
# 1
# 09/05/2014
# 2
# 04/20/2014
# 2
# 04/20/2013
# 2
# 04/20/2012
# 1
# 04/16/2014
# 1
# 04/10/2014
# 2
# 07/17/2012
# 1
# 06/29/2012
# 2
# 05/22/1989
# 2
# 05/22/2010
# https://thejetpaxx.bandcamp.com
# 3
# 06/27/2011
# https://thenoones.bandcamp.com
# 3
# 06/28/2011
# https://falsetropics.bandcamp.com
# 3
# 10/30/2018
# https://thedownstream.bandcamp.com
# 2
# 06/28/2019
# 2
# 11/29/2017
# https://writersblock.bandcamp.com
# 3
# 10/10/2012
# https://manchildcalgary.bandcamp.com
# 3
# 07/28/2013
# https://unfestinsagital.bandcamp.com
# 2
# 06/15/2019
# 2
# 01/05/2018
# 2
# 05/10/2017
# 2
# 08/31/2015
# 2
# 09/28/2015
# 2
# 11/05/2015
# 2
# 04/16/2015
# 2
# 10/22/2014
# 2
# 01/14/2014
# 2
# 01/03/2014
# 2
# 10/25/2013
# 2
# 08/29/2012
# 2
# 01/10/2012
# 2
# 11/26/2012
# 2
# 02/04/2014
# 2
# 11/04/2013
# 2
# 09/16/2016
# 2
# 04/25/2016
# 2
# 04/21/2016
# 2
# 04/16/2016
# https://bluemako.bandcamp.com
# 2
# 12/31/2011
# 2
# 08/05/2011
# 2
# 07/10/2011
# 2
# 04/19/2011
# https://ihateyoujustkidding.bandcamp.com
# 2
# 02/02/2018
# 2
# 07/04/2011
# 2
# 03/01/2011
# 2
# 07/19/2010
